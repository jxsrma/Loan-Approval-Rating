# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('cleaned_loan_data.csv')
df
# Out:
#       loan_id  no_of_dependents  education  self_employed  income_annum  \
# 0           1         -0.294102          0              0      1.617979
# 1           2         -1.473548          1              1     -0.341750
# 2           3          0.295621          0              0      1.439822
# 3           4          0.295621          0              0      1.119139
# 4           5          1.475067          1              1      1.689242
# ...       ...               ...        ...            ...           ...
# 4264     4265          1.475067          0              1     -1.446324
# 4265     4266         -1.473548          1              1     -0.626801
# 4266     4267         -0.294102          1              0      0.513405
# 4267     4268         -0.883825          1              0     -0.341750
# 4268     4269         -0.883825          0              0      1.475453
#
#       loan_amount  loan_term  cibil_score  residential_assets_value  \
# ...

# %%
# Out:
# <Axes: xlabel='income_annum', ylabel='no_of_dependents'>
